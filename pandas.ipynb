# %%
import pandas as pd
import numpy as np

# %%
d = {
    'A': [1,2, np.nan],
    'B':[5, np.nan, np.nan],
    'C':[1,2,3]
}
df = pd.DataFrame(d)
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
d = {
    'A': [1,2,3],
    'B':[5, 6,7]
}
df = pd.DataFrame(d)
df
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7

# %%
df.dropna()
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7

# %%
df.dropna(axis = 0)
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7

# %%
df.dropna??

# %%
df.dropna(axis = 1)
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value = 'Filling Value')
# Out:
#                A              B  C
# 0            1.0            5.0  1
# 1            2.0  Filling Value  2
# 2  Filling Value  Filling Value  3

# %%
df = pd.DataFrame(d)
a = df['A'].fillna(value = df['A'].mean())
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
a
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df['A'].fillna(value = df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  1.5  NaN  3

# %%
df.fillna??
df['A'].fillna(value = df['A'].mean(), inplace = True)
df
# Out:
# <ipython-input-68-f8097b6f5252>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(value = df['A'].mean(), inplace = True)
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  1.5  NaN  3

# %%
data = {
    'Company':['Google', 'Google', 'MSFT', 'FB','FB','IBM'],
    'Person': ['Sam','Nihad','Any','Van','Rakib','Ovi'],
    'Sales': [200, 120, 340, 124, 243, 350]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df = pd.DataFrame(data)

# %%
byComp = df.groupby('Company')
byComp['Sales'].mean()
# Out:
# Company
# FB        183.5
# Google    160.0
# IBM       350.0
# MSFT      340.0
# Name: Sales, dtype: float64

# %%
byComp.sum()
# Out:
#            Person  Sales
# Company
# FB       VanRakib    367
# Google   SamNihad    320
# IBM           Ovi    350
# MSFT          Any    340

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean        std    min     25%    50%     75%    max
# Company
# FB        2.0  183.5  84.145707  124.0  153.75  183.5  213.25  243.0
# Google    2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# IBM       1.0  350.0        NaN  350.0  350.00  350.0  350.00  350.0
# MSFT      1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0

# %%
df.groupby('Company').count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# Google        2      2
# IBM           1      1
# MSFT          1      1

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean        std    min     25%    50%     75%    max
# Company
# FB        2.0  183.5  84.145707  124.0  153.75  183.5  213.25  243.0
# Google    2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# IBM       1.0  350.0        NaN  350.0  350.00  350.0  350.00  350.0
# MSFT      1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0

# %%
import pandas as pd
import numpy as np
d = {
    'A': [1,2, np.nan],
    'B':[5, np.nan, np.nan],
    'C':[1,2,3]
}
df = pd.DataFrame(d)
df
df.dropna()
df.dropna(axis = 0)
df
df.fillna(value = 'Filling Value')
df = pd.DataFrame(d)
a = df['A'].fillna(value = df['A'].mean())
df
a
df
df['A'].fillna(value = df['A'].mean())
df
df['A'].fillna(value = df['A'].mean(), inplace = True)
df
data = {
    'Company':['Google', 'Google', 'MSFT', 'FB','FB','IBM'],
    'Person': ['Sam','Nihad','Any','Van','Rakib','Ovi'],
    'Sales': [200, 120, 340, 124, 243, 350]
}
df = pd.DataFrame(data)
df
byComp = df.groupby('Company')
byComp['Sales'].mean()
byComp.sum()
df
df.groupby('Company').describe()
df.groupby('Company').count()
df
df.groupby('Company').describe()
# Out:
# <ipython-input-1-449abe84d52b>:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(value = df['A'].mean(), inplace = True)
#         Sales
#         count   mean        std    min     25%    50%     75%    max
# Company
# FB        2.0  183.5  84.145707  124.0  153.75  183.5  213.25  243.0
# Google    2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# IBM       1.0  350.0        NaN  350.0  350.00  350.0  350.00  350.0
# MSFT      1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0

# %%
df1 = pd.DataFrame(np.random.randint(1, 20, size = (4, 3)), [1,2,3,4], ['W', 'X', 'Y'])
df2 = pd.DataFrame(np.random.randint(20,40, size = (4, 3)), [5,6,7,8], ['W', 'X', 'Y'])
df3 = pd.DataFrame(np.random.randint(40,60, size = (4, 3)), [9,10,11,12], ['W', 'X', 'Y'])
df1
# Out:
#     W   X   Y
# 1  14   6   7
# 2  12  12  19
# 3  18  18  16
# 4   2  11   8

# %%
df2
# Out:
#     W   X   Y
# 5  35  21  33
# 6  38  23  38
# 7  30  28  25
# 8  21  23  24

# %%
df3
# Out:
#      W   X   Y
# 9   41  54  58
# 10  46  46  47
# 11  41  52  41
# 12  54  51  59

# %%
Frame = [df1, df2, df3]
pd.concat(Frame)
# Out:
#      W   X   Y
# 1   14   6   7
# 2   12  12  19
# 3   18  18  16
# 4    2  11   8
# 5   35  21  33
# 6   38  23  38
# 7   30  28  25
# 8   21  23  24
# 9   41  54  58
# 10  46  46  47
# 11  41  52  41
# 12  54  51  59

# %%
pd.concat(Frame, axis = 1)
# Out:
#        W     X     Y     W     X     Y     W     X     Y
# 1   14.0   6.0   7.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2   12.0  12.0  19.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3   18.0  18.0  16.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4    2.0  11.0   8.0   NaN   NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN  35.0  21.0  33.0   NaN   NaN   NaN
# 6    NaN   NaN   NaN  38.0  23.0  38.0   NaN   NaN   NaN
# 7    NaN   NaN   NaN  30.0  28.0  25.0   NaN   NaN   NaN
# 8    NaN   NaN   NaN  21.0  23.0  24.0   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN  41.0  54.0  58.0
# 10   NaN   NaN   NaN   NaN   NaN   NaN  46.0  46.0  47.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN  41.0  52.0  41.0
# 12   NaN   NaN   NaN   NaN   NaN   NaN  54.0  51.0  59.0

# %%
left = {
    'key':['k0','k1','k2','k3'],
    'A':[10,20,30,40],
    'B':[1,2,3,4]
}
right = {
    'key':['k0','k1','k2','k3'],
    'C':[100,200,300,400],
    'D':[11,12,13,14]
}
left = pd.DataFrame(left)
right = pd.DataFrame(right)
left
# Out:
#   key   A  B
# 0  k0  10  1
# 1  k1  20  2
# 2  k2  30  3
# 3  k3  40  4

# %%
right
# Out:
#   key    C   D
# 0  k0  100  11
# 1  k1  200  12
# 2  k2  300  13
# 3  k3  400  14

# %%
pd.merge(left, right, on='key')
# Out:
#   key   A  B    C   D
# 0  k0  10  1  100  11
# 1  k1  20  2  200  12
# 2  k2  30  3  300  13
# 3  k3  40  4  400  14

# %%
left = {
    'A':['A0','A1','A2'],
    'B':['B0','B1','B2']
}
right = {
    'C':['C0','C2','C3'],
    'D':['D0','D2','D3']
}
left = pd.DataFrame(left, index = ['K0','K1','K2'])
right = pd.DataFrame(right, index = ['K0','K2','K3'])
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
left.join(right, how = 'inner')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
df = pd.DataFrame({
    'col1':[444,555,666,444],
    'col2':[1,2,3,4],
    'col3':['abc','def','ghi','xyz']
})
df
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df['col1'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col1'].nunique()
# Out:
# 3

# %%
df['col1'].value_counts()
# Out:
# col1
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
def times2(x):
    return 2*x

# %%
df['col2'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col2, dtype: int64

# %%
df['col2'].apply(lambda x: x**2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col2, dtype: int64

# %%
df = pd.read_excel('/content/SampleData.xlsx', sheet_name = 'SalesOrders')

# %%
df.head(10)
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df.tail()
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df.columns.to_list()
# Out:
# ['col1', 'col2', 'col3']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    4 non-null      int64
#  1   col2    4 non-null      int64
#  2   col3    4 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.nunique()
# Out:
# col1    3
# col2    4
# col3    4
# dtype: int64

# %%
df.head()
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df['20% Dis'] = df['Total'].apply(lambda x: x*(20/100))

# %%
df.head()
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df['Payment'] = df['Total'] - df['20% Dis']

# %%
df.head()
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (12,6))
plt.plot(df['OrderDate'], df['Total'])
plt.show()
