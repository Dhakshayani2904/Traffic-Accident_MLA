# %%
x = 5

# %%
y="john"

# %%
print(x)
# Out:
# 5

# %%
print(y)
# Out:
# john

# %%
X=4

# %%
x="sally"

# %%
print(x)
# Out:
# sally

# %%
x=str(3)

# %%
y=int(3)

# %%
z=float(3)

# %%
print(x)
# Out:
# 3

# %%
print(y)
# Out:
# 3

# %%
print(z)
# Out:
# 3.0

# %%
x=5

# %%
y="john"

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
a=4

# %%
A="sally"

# %%
print(A)
# Out:
# sally

# %%
print(a)
# Out:
# 4

# %%
x,y,z="orange","Banana","cherry"

# %%
print(x)
# Out:
# orange

# %%
print(y)
# Out:
# Banana

# %%
print(z)
# Out:
# cherry

# %%
x=y=z="orange"

# %%
print(x)
# Out:
# orange

# %%
print(y)
# Out:
# orange

# %%
print(z)
# Out:
# orange

# %%
fruits=["apple","Banana","cherry"]

# %%
x,y,z=fruits

# %%
print(x)
# Out:
# apple

# %%
print(y)
# Out:
# Banana

# %%
print(z)
# Out:
# cherry

# %%
x="python"

# %%
y="is"

# %%
z="awesome"

# %%
print(x,y,z)
# Out:
# python is awesome

# %%
x=5

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x=1

# %%
y=2.8

# %%
z=1j

# %%
print(x)
# Out:
# 1

# %%
print(y)
# Out:
# 2.8

# %%
print(z)
# Out:
# 1j

# %%
x=1

# %%
y=35656222554887711

# %%
z=-3255522

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'int'>

# %%
print(type(z))
# Out:
# <class 'int'>

# %%
x=1.10

# %%
y=1.0

# %%
z=-35.59

# %%
print(type(x))
# Out:
# <class 'float'>

# %%
print(type(y))
# Out:
# <class 'float'>

# %%
print(type(z))
# Out:
# <class 'float'>

# %%
x=3+5j

# %%
y=5j

# %%
z=-5j

# %%
print(type(x))
# Out:
# <class 'complex'>

# %%
print(type(y))
# Out:
# <class 'complex'>

# %%
print(type(z))
# Out:
# <class 'complex'>

# %%
x=1

# %%
y=2.8

# %%
z=1j

# %%
a=float(x)

# %%
b=int(y)

# %%
c=complex(x)

# %%
print(a)
# Out:
# 1.0

# %%
print(b)
# Out:
# 2

# %%
print(c)
# Out:
# (1+0j)

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
print(type(c))
# Out:
# <class 'complex'>

# %%
x=int(1)

# %%
y=int(2.8)

# %%
z=int("3")

# %%
print(x)
# Out:
# 1.0

# %%
print(y)
# Out:
# 2.8

# %%
print(z)
# Out:
# 3

# %%
x=float(1)

# %%
y=float(2.8)

# %%
z=float("3")

# %%
w=float("4.2")

# %%
print(x)
# Out:
# 1.0

# %%
print(y)
# Out:
# 2.8

# %%
print(z)
# Out:
# 3

# %%
print(w)
# Out:
# 4.2

# %%
x=str("st")

# %%
y=str(2)

# %%
z=str(3.0)

# %%
print(x)
# Out:
# st

# %%
print(y)
# Out:
# 2

# %%
print(z)
# Out:
# 3.0

# %%
a="Hello"

# %%
print(a)
# Out:
# Hello

# %%
a="""Lorem ipsum dolor sit amet,consectetur adipiscing slit,sed,do eiusmod tempor incididunt ut labore et dolore magna aliqua."""

# %%
print(a)
# Out:
# Lorem ipsum dolor sit amet,consectetur adipiscing slit,sed,do eiusmod tempor incididunt ut labore et dolore magna aliqua.

# %%
a="Hello,World"

# %%
print(a[1])
# Out:
# e

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
a="Hello,World"

# %%
print(len(a))
# Out:
# 11

# %%
txt="The best things in life are free!"
print("free in txt")
# Out:
# free in txt

# %%
txt="The best things in life are free!"
if"free"in txt:
 print("yes,'free'is present")
# Out:
# yes,'free'is present

# %%
txt="The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %%
a=b="Hello,World"
print(b[2:5])
print(b[:5])
print(b[:5])
print(b[2:])
print(b[-5:-2])
# Out:
# llo
# Hello
# Hello
# llo,World
# Wor

# %%
a="Hello,World!"
print(a.upper())
# Out:
# HELLO,WORLD!

# %%
a="Hello,World!"
print(a.lower())
# Out:
# hello,world!

# %%
a="Hello,World!"
print(a.strip())
# Out:
# Hello,World!

# %%
a="Hello,World!"
print(a.replace("H","j"))
# Out:
# jello,World!

# %%
a="Hello,World!"
print(a.split(","))
# Out:
# ['Hello', 'World!']

# %%
a="Hello"
b="world"
c=a+b
print(c)
# Out:
# Helloworld

# %%
print(10>9)
print(10==9)
print(10<9)
# Out:
# True
# False
# False

# %%
a=200
b=33
if b>a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
mylist=["apple","banana","cherry"]

# %%
thislist=["apple","banana","cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist  = ["apple","banana","cherry","apple","cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
thislist  = ["apple","banana","cherry"]
print(len(thislist))
# Out:
# 3

# %%
list1=["apple","banana","cherry"]
list2=[1,5,7,9,3]
list3=[True,False,False]
print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'banana', 'cherry']
# [1, 5, 7, 9, 3]
# [True, False, False]

# %%
list1=["abc",34,True,40,"male"]
print(list1)
# Out:
# ['abc', 34, True, 40, 'male']

# %%
mylist=["apple","banana","cherry"]
print(type(mylist))
# Out:
# <class 'list'>

# %%
thislist=list(("apple","banana","cherry"))
print(thislist[1])
# Out:
# banana

# %%
thislist=["apple","banana","cherry"]
print(thislist[-1])
# Out:
# cherry

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[:4])
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[-4:-1])
# Out:
# ['orange', 'kiwi', 'melon']

# %%
thislist=["apple","banana","cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist=["apple","banana","cherry"]
thislist.insert(1,"orange")
print(thislist)
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %%
thislist=["apple","banana","cherry"]
for x in thislist:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
thislist=["apple","banana","cherry"]
for i in range(len(thislist)):
  print(thislist[i])
# Out:
# apple
# banana
# cherry

# %%
mytuple=("apple","banana","cherry")
print(mytuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple=("apple","banana","cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple = ("apple","banana","cherry")
print(thistuple[1])
# Out:
# banana

# %%
thistuple=("apple","banana","cherry")
print(thistuple[-1])
# Out:
# cherry

# %%
thidtuple=("apple","banana","cherry","orange","kiwi","melon","mango")
print(thidtuple[2:5])
# Out:
# ('cherry', 'orange', 'kiwi')

# %%
thistuple=("apple","banana","cherry","orange","kiwi","melon","mango")
print(thistuple[:4])
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
 myset={"apple","banana","cherry"}
 print(myset)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
thisset={"apple","banana","cherry",True,1,2}
print(thisset)
# Out:
# {True, 2, 'banana', 'cherry', 'apple'}

# %%
thisset={"apple","banana","cherry"}
print(len(thisset))
# Out:
# 3

# %%
set1={"apple","banana","cherry"}
set2={1,5,7,9,3}
set3={True,False,False}
print(set1)
print(set2)
print(set3)
# Out:
# {'banana', 'cherry', 'apple'}
# {1, 3, 5, 7, 9}
# {False, True}

# %%
set1={"abc ",34,True,40,"male"}
print(set1)
# Out:
# {True, 34, 'male', 'abc ', 40}

# %%
thisset={"apple","banana","cherry"}
for x in thisset:
  print(x)
# Out:
# banana
# cherry
# apple

# %%
thisset={"apple","banana","cherry"}
thisset.add("orange")
print(thisset)
# Out:
# {'banana', 'cherry', 'apple', 'orange'}

# %%
set1={"a","b","c"}
set2={1,2,3}
set3=set1.union(set2)
print(set3)
# Out:
# {1, 2, 3, 'b', 'c', 'a'}

# %%
set1={"a","b","c",}
set2={1,2,3}
set3=set1|set2
print(set3)
# Out:
# {1, 2, 3, 'b', 'c', 'a'}

# %%
set1={"a","b","c"}
set2={1,2,3}
set3={"john","elena"}
set4={"apple","banana","cherry"}
set5=set1.union(set2,set3,set4)
print(set5)
# Out:
# {1, 2, 3, 'banana', 'cherry', 'elena', 'c', 'john', 'b', 'apple', 'a'}
